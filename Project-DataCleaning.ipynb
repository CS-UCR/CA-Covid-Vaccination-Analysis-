# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =  pd.read_csv("CA_Vaccine_Data.csv") 
df
# Out:
#                 county administered_date  total_doses  cumulative_total_doses  \
# 0      All CA Counties        2020-12-15         1238                    1238
# 1      All CA Counties        2020-12-16         9021                   10259
# 2      All CA Counties        2020-12-17        27137                   37396
# 3      All CA Counties        2020-12-18        46006                   83402
# 4      All CA Counties        2020-12-19        25773                  109175
# ...                ...               ...          ...                     ...
# 15309             Yuba        2021-08-14          138                   53901
# 15310             Yuba        2021-08-15           85                   53986
# 15311             Yuba        2021-08-16          216                   54202
# 15312             Yuba        2021-08-17          189                   54391
# 15313             Yuba        2021-08-18          130                   54521
#
# ...

# %%
# RENAME ALL THE COLUMNS TO PROPERLY VISUALIZE!

# %%
df.rename(columns={'county':'California Counties','administered_date':'Dose Date YYY-DD-MM', 'total_doses':'Total Doses', 'cumulative_total_doses':'Cumulative Total',
                   'pfizer_doses': 'PFIZER', 'cumulative_pfizer_doses':'PFIZER TOTAL','moderna_doses':'MODERNA','cumulative_moderna_doses':'MODERNA TOTAL',
                     'jj_doses':'JANSSEN','cumulative_jj_doses':'JANSSEN TOTAL','partially_vaccinated':'Partially Vaccinated',
                       'total_partially_vaccinated':'TOTAL Partially Vaccinated','fully_vaccinated':'Fully Vaccinated','cumulative_fully_vaccinated':'TOTAL Fully Vaccinated',
                         'at_least_one_dose':'One Dose Taken','cumulative_at_least_one_dose':'TOTAL One Doses Taken'}, inplace = True)
df
# Out:
#       California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 0         All CA Counties          2020-12-15         1238              1238
# 1         All CA Counties          2020-12-16         9021             10259
# 2         All CA Counties          2020-12-17        27137             37396
# 3         All CA Counties          2020-12-18        46006             83402
# 4         All CA Counties          2020-12-19        25773            109175
# ...                   ...                 ...          ...               ...
# 15309                Yuba          2021-08-14          138             53901
# 15310                Yuba          2021-08-15           85             53986
# 15311                Yuba          2021-08-16          216             54202
# 15312                Yuba          2021-08-17          189             54391
# 15313                Yuba          2021-08-18          130             54521
#
# ...

# %%
df.drop(["california_flag"],axis=1, inplace = True)
df.set_index('California Counties', inplace = True)
df.drop(labels = ["Unknown", "All CA and Non-CA Counties", "Outside California"], axis=0, inplace = True)
df.reset_index(inplace = True)
df
# Out:
#       California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 0         All CA Counties          2020-12-15         1238              1238
# 1         All CA Counties          2020-12-16         9021             10259
# 2         All CA Counties          2020-12-17        27137             37396
# 3         All CA Counties          2020-12-18        46006             83402
# 4         All CA Counties          2020-12-19        25773            109175
# ...                   ...                 ...          ...               ...
# 14568                Yuba          2021-08-14          138             53901
# 14569                Yuba          2021-08-15           85             53986
# 14570                Yuba          2021-08-16          216             54202
# 14571                Yuba          2021-08-17          189             54391
# 14572                Yuba          2021-08-18          130             54521
#
# ...

# %%
for col in df:
    print(df[col].unique())
# Out:
# ['All CA Counties' 'Alpine' 'Amador' 'Butte' 'Calaveras' 'Colusa'
#  'Del Norte' 'Glenn' 'Humboldt' 'Imperial' 'Inyo' 'Kings' 'Lake' 'Lassen'
#  'Madera' 'Marin' 'Mariposa' 'Mendocino' 'Merced' 'Modoc' 'Mono'
#  'Monterey' 'Napa' 'Nevada' 'Plumas' 'San Benito' 'Santa Barbara' 'Shasta'
#  'Sierra' 'Siskiyou' 'Stanislaus' 'Sutter' 'Tehama' 'Trinity' 'Tulare'
#  'Tuolumne' 'Yuba' 'Alameda' 'Contra Costa' 'El Dorado' 'Fresno' 'Kern'
#  'Los Angeles' 'Orange' 'Placer' 'Riverside' 'Sacramento' 'San Bernardino'
#  'San Diego' 'San Francisco' 'San Joaquin' 'San Luis Obispo' 'San Mateo'
#  'Santa Clara' 'Santa Cruz' 'Solano' 'Sonoma' 'Ventura' 'Yolo']
# ['2020-12-15' '2020-12-16' '2020-12-17' '2020-12-18' '2020-12-19'
#  '2020-12-20' '2020-12-21' '2020-12-22' '2020-12-23' '2020-12-24'
#  '2020-12-25' '2020-12-26' '2020-12-27' '2020-12-28' '2020-12-29'
#  '2020-12-30' '2020-12-31' '2021-01-01' '2021-01-02' '2021-01-03'
#  '2021-01-04' '2021-01-05' '2021-01-06' '2021-01-07' '2021-01-08'
# ...
