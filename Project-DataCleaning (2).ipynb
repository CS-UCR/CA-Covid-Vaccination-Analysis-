# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =  pd.read_csv("CA_Vaccine_Data.csv") 
df
# Out:
#                 county administered_date  total_doses  cumulative_total_doses  \
# 0      All CA Counties        2020-12-15         1238                    1238
# 1      All CA Counties        2020-12-16         9021                   10259
# 2      All CA Counties        2020-12-17        27137                   37396
# 3      All CA Counties        2020-12-18        46006                   83402
# 4      All CA Counties        2020-12-19        25773                  109175
# ...                ...               ...          ...                     ...
# 15309             Yuba        2021-08-14          138                   53901
# 15310             Yuba        2021-08-15           85                   53986
# 15311             Yuba        2021-08-16          216                   54202
# 15312             Yuba        2021-08-17          189                   54391
# 15313             Yuba        2021-08-18          130                   54521
#
# ...

# %%
# RENAME ALL THE COLUMNS TO PROPERLY VISUALIZE!

# %%
df.rename(columns={'county':'California Counties','administered_date':'Dose Date YYY-DD-MM', 'total_doses':'Total Doses', 'cumulative_total_doses':'Cumulative Total',
                   'pfizer_doses': 'PFIZER', 'cumulative_pfizer_doses':'PFIZER TOTAL','moderna_doses':'MODERNA','cumulative_moderna_doses':'MODERNA TOTAL',
                     'jj_doses':'JANSSEN','cumulative_jj_doses':'JANSSEN TOTAL','partially_vaccinated':'Partially Vaccinated',
                       'total_partially_vaccinated':'TOTAL Partially Vaccinated','fully_vaccinated':'Fully Vaccinated','cumulative_fully_vaccinated':'TOTAL Fully Vaccinated',
                         'at_least_one_dose':'One Dose Taken','cumulative_at_least_one_dose':'TOTAL One Doses Taken'}, inplace = True)
df
# Out:
#       California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 0         All CA Counties          2020-12-15         1238              1238
# 1         All CA Counties          2020-12-16         9021             10259
# 2         All CA Counties          2020-12-17        27137             37396
# 3         All CA Counties          2020-12-18        46006             83402
# 4         All CA Counties          2020-12-19        25773            109175
# ...                   ...                 ...          ...               ...
# 15309                Yuba          2021-08-14          138             53901
# 15310                Yuba          2021-08-15           85             53986
# 15311                Yuba          2021-08-16          216             54202
# 15312                Yuba          2021-08-17          189             54391
# 15313                Yuba          2021-08-18          130             54521
#
# ...

# %%
#BELOW ARE ROWS THAT CONTAINS 'UNKNOWN' UNDER CALIFORNIA COUNTIES. THEREFORE, WE WILL GET RID OF THEM.

# %%
df.iloc[1187:1416]
# Out:
#      California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 1187             Unknown          2020-12-18            1                 3
# 1188             Unknown          2020-12-21            4                 7
# 1189             Unknown          2020-12-28            1                 8
# 1190             Unknown          2020-12-29            2                10
# 1191             Unknown          2020-12-30           54                64
# ...                  ...                 ...          ...               ...
# 1411             Unknown          2021-08-14           10              3371
# 1412             Unknown          2021-08-15            4              3375
# 1413             Unknown          2021-08-16           10              3385
# 1414             Unknown          2021-08-17           10              3395
# 1415             Unknown          2021-08-18            5              3400
#
# ...

# %%
df[df["California Counties"].str.contains("Unknown")==False]
# Out:
#       California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 0         All CA Counties          2020-12-15         1238              1238
# 1         All CA Counties          2020-12-16         9021             10259
# 2         All CA Counties          2020-12-17        27137             37396
# 3         All CA Counties          2020-12-18        46006             83402
# 4         All CA Counties          2020-12-19        25773            109175
# ...                   ...                 ...          ...               ...
# 15308                Yuba          2021-08-13          233             53763
# 15309                Yuba          2021-08-14          138             53901
# 15310                Yuba          2021-08-15           85             53986
# 15311                Yuba          2021-08-16          216             54202
# 15312                Yuba          2021-08-17          189             54391
#
# ...

# %%
# Before we had 15314 rows in total, after dropping rows with "Unknown" we were left with 15066 rows as total.

# %%
# Next, we will remove rows with "Outside California" data, since we don't need that.

# %%
# Dsipay the rows that has the data counties that are not part of california.

# %%
df.iloc[922:1169]
# Out:
#      California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 939   Outside California          2020-12-15           12                12
# 940   Outside California          2020-12-16          254               266
# 941   Outside California          2020-12-17         1490              1756
# 942   Outside California          2020-12-18         2306              4062
# 943   Outside California          2020-12-19          944              5006
# ...                  ...                 ...          ...               ...
# 1181  Outside California          2021-08-14         1141            785261
# 1182  Outside California          2021-08-15          741            786002
# 1183  Outside California          2021-08-16         1545            787547
# 1184  Outside California          2021-08-17         1655            789202
# 1185  Outside California          2021-08-18         1079            790281
#
# ...

# %%
# Now, we will remove above rows.

# %%
df[df["California Counties"].str.contains("Outside California")==False]
# Out:
#       California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 0         All CA Counties          2020-12-15         1238              1238
# 1         All CA Counties          2020-12-16         9021             10259
# 2         All CA Counties          2020-12-17        27137             37396
# 3         All CA Counties          2020-12-18        46006             83402
# 4         All CA Counties          2020-12-19        25773            109175
# ...                   ...                 ...          ...               ...
# 15308                Yuba          2021-08-13          233             53763
# 15309                Yuba          2021-08-14          138             53901
# 15310                Yuba          2021-08-15           85             53986
# 15311                Yuba          2021-08-16          216             54202
# 15312                Yuba          2021-08-17          189             54391
#
# ...

# %%
# After removing rows with "Outside California" we are now left with 14819 rows in total.

# %%
# Next,this dataset contains data for the Cumiliative "All CA and non-CA counties" which we are not required. 
# This data contains from 248-493 as we an see it from below.

# %%
df.iloc[248:494]
# Out:
#             California Counties Dose Date YYY-DD-MM  Total Doses  \
# 248  All CA and Non-CA Counties          2020-12-16         9275
# 249  All CA and Non-CA Counties          2020-12-17        28629
# 250  All CA and Non-CA Counties          2020-12-18        48313
# 251  All CA and Non-CA Counties          2020-12-19        26717
# 252  All CA and Non-CA Counties          2020-12-20        19934
# ..                          ...                 ...          ...
# 489  All CA and Non-CA Counties          2021-08-14        70524
# 490  All CA and Non-CA Counties          2021-08-15        36838
# 491  All CA and Non-CA Counties          2021-08-16        93722
# 492  All CA and Non-CA Counties          2021-08-17        96626
# 493  All CA and Non-CA Counties          2021-08-18        49794
#
#      Cumulative Total  PFIZER  PFIZER TOTAL  MODERNA  MODERNA TOTAL  JANSSEN  \
# 248             10525    9275         10525        0              0        0
# ...

# %%
# Now, removing above rows

# %%
df[df["California Counties"].str.contains("All CA and Non-CA Counties")==False]
# Out:
#       California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 0         All CA Counties          2020-12-15         1238              1238
# 1         All CA Counties          2020-12-16         9021             10259
# 2         All CA Counties          2020-12-17        27137             37396
# 3         All CA Counties          2020-12-18        46006             83402
# 4         All CA Counties          2020-12-19        25773            109175
# ...                   ...                 ...          ...               ...
# 15308                Yuba          2021-08-13          233             53763
# 15309                Yuba          2021-08-14          138             53901
# 15310                Yuba          2021-08-15           85             53986
# 15311                Yuba          2021-08-16          216             54202
# 15312                Yuba          2021-08-17          189             54391
#
# ...

# %%
df.drop
# Out:
#       California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 0         All CA Counties          2020-12-15         1238              1238
# 1         All CA Counties          2020-12-16         9021             10259
# 2         All CA Counties          2020-12-17        27137             37396
# 3         All CA Counties          2020-12-18        46006             83402
# 4         All CA Counties          2020-12-19        25773            109175
# ...                   ...                 ...          ...               ...
# 15308                Yuba          2021-08-13          233             53763
# 15309                Yuba          2021-08-14          138             53901
# 15310                Yuba          2021-08-15           85             53986
# 15311                Yuba          2021-08-16          216             54202
# 15312                Yuba          2021-08-17          189             54391
#
# ...
