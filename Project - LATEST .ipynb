# %%
import pandas as pd
#pd.to_datetime('2020-12-15 3:45pm')
import numpy as np
import matplotlib.pyplot as plt

# %%
df =  pd.read_csv("CA_Vaccine_Data.csv") 
df
# Out:
#                 county administered_date  total_doses  cumulative_total_doses  \
# 0      All CA Counties        2020-12-15         1238                    1238
# 1      All CA Counties        2020-12-16         9021                   10259
# 2      All CA Counties        2020-12-17        27137                   37396
# 3      All CA Counties        2020-12-18        46006                   83402
# 4      All CA Counties        2020-12-19        25773                  109175
# ...                ...               ...          ...                     ...
# 15309             Yuba        2021-08-14          138                   53901
# 15310             Yuba        2021-08-15           85                   53986
# 15311             Yuba        2021-08-16          216                   54202
# 15312             Yuba        2021-08-17          189                   54391
# 15313             Yuba        2021-08-18          130                   54521
#
# ...

# %%
# DATA CLEANING:-
# RENAME ALL THE COLUMNS TO PROPERLY VISUALIZE!

# %%
df.rename(columns={'county':'California Counties','administered_date':'Dose Date YYY-DD-MM', 'total_doses':'Total Doses', 'cumulative_total_doses':'Cumulative Total',
                   'pfizer_doses': 'PFIZER', 'cumulative_pfizer_doses':'PFIZER TOTAL','moderna_doses':'MODERNA','cumulative_moderna_doses':'MODERNA TOTAL',
                     'jj_doses':'JANSSEN','cumulative_jj_doses':'JANSSEN TOTAL','partially_vaccinated':'Partially Vaccinated',
                       'total_partially_vaccinated':'TOTAL Partially Vaccinated','fully_vaccinated':'Fully Vaccinated','cumulative_fully_vaccinated':'TOTAL Fully Vaccinated',
                         'at_least_one_dose':'One Dose Taken','cumulative_at_least_one_dose':'TOTAL One Doses Taken'}, inplace = True)
df
# Out:
#       California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 0         All CA Counties          2020-12-15         1238              1238
# 1         All CA Counties          2020-12-16         9021             10259
# 2         All CA Counties          2020-12-17        27137             37396
# 3         All CA Counties          2020-12-18        46006             83402
# 4         All CA Counties          2020-12-19        25773            109175
# ...                   ...                 ...          ...               ...
# 15309                Yuba          2021-08-14          138             53901
# 15310                Yuba          2021-08-15           85             53986
# 15311                Yuba          2021-08-16          216             54202
# 15312                Yuba          2021-08-17          189             54391
# 15313                Yuba          2021-08-18          130             54521
#
# ...

# %%
df.drop(["california_flag"],axis=1, inplace = True)
df.set_index('California Counties', inplace = True)
df.drop(labels = ["Unknown", "All CA and Non-CA Counties", "Outside California"], axis=0, inplace = True)
df.reset_index(inplace = True)
df
# Out:
#       California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 0         All CA Counties          2020-12-15         1238              1238
# 1         All CA Counties          2020-12-16         9021             10259
# 2         All CA Counties          2020-12-17        27137             37396
# 3         All CA Counties          2020-12-18        46006             83402
# 4         All CA Counties          2020-12-19        25773            109175
# ...                   ...                 ...          ...               ...
# 14568                Yuba          2021-08-14          138             53901
# 14569                Yuba          2021-08-15           85             53986
# 14570                Yuba          2021-08-16          216             54202
# 14571                Yuba          2021-08-17          189             54391
# 14572                Yuba          2021-08-18          130             54521
#
# ...

# %%
for col in df:
    print(df[col].unique())
# Out:
# ['All CA Counties' 'Alpine' 'Amador' 'Butte' 'Calaveras' 'Colusa'
#  'Del Norte' 'Glenn' 'Humboldt' 'Imperial' 'Inyo' 'Kings' 'Lake' 'Lassen'
#  'Madera' 'Marin' 'Mariposa' 'Mendocino' 'Merced' 'Modoc' 'Mono'
#  'Monterey' 'Napa' 'Nevada' 'Plumas' 'San Benito' 'Santa Barbara' 'Shasta'
#  'Sierra' 'Siskiyou' 'Stanislaus' 'Sutter' 'Tehama' 'Trinity' 'Tulare'
#  'Tuolumne' 'Yuba' 'Alameda' 'Contra Costa' 'El Dorado' 'Fresno' 'Kern'
#  'Los Angeles' 'Orange' 'Placer' 'Riverside' 'Sacramento' 'San Bernardino'
#  'San Diego' 'San Francisco' 'San Joaquin' 'San Luis Obispo' 'San Mateo'
#  'Santa Clara' 'Santa Cruz' 'Solano' 'Sonoma' 'Ventura' 'Yolo']
# ['2020-12-15' '2020-12-16' '2020-12-17' '2020-12-18' '2020-12-19'
#  '2020-12-20' '2020-12-21' '2020-12-22' '2020-12-23' '2020-12-24'
#  '2020-12-25' '2020-12-26' '2020-12-27' '2020-12-28' '2020-12-29'
#  '2020-12-30' '2020-12-31' '2021-01-01' '2021-01-02' '2021-01-03'
#  '2021-01-04' '2021-01-05' '2021-01-06' '2021-01-07' '2021-01-08'
# ...

# %%
import matplotlib
# %matplotlib inline

# %%
df.groupby('Dose Date YYY-DD-MM')[['PFIZER TOTAL', 'MODERNA TOTAL', 'JANSSEN TOTAL']].mean().plot.hist(bins=70)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Checking the data type 
df.dtypes
# Out:
# California Counties           object
# Dose Date YYY-DD-MM           object
# Total Doses                    int64
# Cumulative Total               int64
# PFIZER                         int64
# PFIZER TOTAL                   int64
# MODERNA                        int64
# MODERNA TOTAL                  int64
# JANSSEN                        int64
# JANSSEN TOTAL                  int64
# Partially Vaccinated           int64
# TOTAL Partially Vaccinated     int64
# Fully Vaccinated               int64
# TOTAL Fully Vaccinated         int64
# One Dose Taken                 int64
# TOTAL One Doses Taken          int64
# dtype: object

# %%
# Setting 'Dose Date' as an index 
df = df.set_index('Dose Date YYY-DD-MM')
df.index
# Out:
# Index(['2020-12-15', '2020-12-16', '2020-12-17', '2020-12-18', '2020-12-19',
#        '2020-12-20', '2020-12-21', '2020-12-22', '2020-12-23', '2020-12-24',
#        ...
#        '2021-08-09', '2021-08-10', '2021-08-11', '2021-08-12', '2021-08-13',
#        '2021-08-14', '2021-08-15', '2021-08-16', '2021-08-17', '2021-08-18'],
#       dtype='object', name='Dose Date YYY-DD-MM', length=14573)

# %%
# Number of PFIZER, MODERNA, JANSSEN Doses taken on particular dates
cols_plot = ['PFIZER', 'MODERNA', 'JANSSEN']
axes = df[cols_plot].plot(marker='.', alpha=1, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Unknown')

# %%
# Comparing how many people are fully vaccinated in Riverside and Los Angeleous counties. 
df.groupby(["California Counties"])["Fully Vaccinated"].mean().loc[["Riverside", "Los Angeles"]].plot.pie()
# Out:
# <AxesSubplot:ylabel='Fully Vaccinated'>

# %%
# Here we are comparing four CA counties to see which vaccine people have taken the most regardless of dose count. 
df.groupby(["California Counties"])[["PFIZER","MODERNA","JANSSEN"]].mean().loc[["Riverside", "Los Angeles", "Orange", "San Diego"]].plot.bar()
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
contain_values = df[df['California Counties'].str.contains('All CA Counties')]
contain_values.reset_index(inplace=True)

contain_values2 = contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2020-12')]
contain_values2.groupby('Dose Date YYY-DD-MM')[['PFIZER TOTAL', 'MODERNA TOTAL', 'JANSSEN TOTAL']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-01')].groupby('Dose Date YYY-DD-MM')[['PFIZER TOTAL', 'MODERNA TOTAL', 'JANSSEN TOTAL']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-02')].groupby('Dose Date YYY-DD-MM')[['PFIZER TOTAL', 'MODERNA TOTAL', 'JANSSEN TOTAL']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-03')].groupby('Dose Date YYY-DD-MM')[['PFIZER TOTAL', 'MODERNA TOTAL', 'JANSSEN TOTAL']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-04')].groupby('Dose Date YYY-DD-MM')[['PFIZER TOTAL', 'MODERNA TOTAL', 'JANSSEN TOTAL']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-05')].groupby('Dose Date YYY-DD-MM')[['PFIZER TOTAL', 'MODERNA TOTAL', 'JANSSEN TOTAL']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-06')].groupby('Dose Date YYY-DD-MM')[['PFIZER TOTAL', 'MODERNA TOTAL', 'JANSSEN TOTAL']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-07')].groupby('Dose Date YYY-DD-MM')[['PFIZER TOTAL', 'MODERNA TOTAL', 'JANSSEN TOTAL']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-08')].groupby('Dose Date YYY-DD-MM')[['PFIZER TOTAL', 'MODERNA TOTAL', 'JANSSEN TOTAL']].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Dose Date YYY-DD-MM'>

# %%
# This data focuses on showing the change of how many people are partially vaccinated and then fully vaccinated over time
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2020-12')].groupby('Dose Date YYY-DD-MM')[['Partially Vaccinated', 'Fully Vaccinated']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-01')].groupby('Dose Date YYY-DD-MM')[['Partially Vaccinated', 'Fully Vaccinated']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-02')].groupby('Dose Date YYY-DD-MM')[['Partially Vaccinated', 'Fully Vaccinated']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-03')].groupby('Dose Date YYY-DD-MM')[['Partially Vaccinated', 'Fully Vaccinated']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-04')].groupby('Dose Date YYY-DD-MM')[['Partially Vaccinated', 'Fully Vaccinated']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-05')].groupby('Dose Date YYY-DD-MM')[['Partially Vaccinated', 'Fully Vaccinated']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-06')].groupby('Dose Date YYY-DD-MM')[['Partially Vaccinated', 'Fully Vaccinated']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-07')].groupby('Dose Date YYY-DD-MM')[['Partially Vaccinated', 'Fully Vaccinated']].mean().plot.bar()
contain_values[contain_values['Dose Date YYY-DD-MM'].str.contains('2021-08')].groupby('Dose Date YYY-DD-MM')[['Partially Vaccinated', 'Fully Vaccinated']].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Dose Date YYY-DD-MM'>

# %%
df.reset_index(inplace=True)
df
# Out:
#       Dose Date YYY-DD-MM California Counties  Total Doses  Cumulative Total  \
# 0              2020-12-15     All CA Counties         1238              1238
# 1              2020-12-16     All CA Counties         9021             10259
# 2              2020-12-17     All CA Counties        27137             37396
# 3              2020-12-18     All CA Counties        46006             83402
# 4              2020-12-19     All CA Counties        25773            109175
# ...                   ...                 ...          ...               ...
# 14568          2021-08-14                Yuba          138             53901
# 14569          2021-08-15                Yuba           85             53986
# 14570          2021-08-16                Yuba          216             54202
# 14571          2021-08-17                Yuba          189             54391
# 14572          2021-08-18                Yuba          130             54521
#
# ...

# %%
# going to limit the data set to only the month of august 2021
# Then visualize how the Total Fully Vaccinated for each county

contain_values3 = df[df['Dose Date YYY-DD-MM'].str.contains('2021-08-18')]
#df.drop(labels = ["Unknown", "All CA and Non-CA Counties", "Outside California"], axis=0, inplace = True)
contain_values3.set_index("California Counties", inplace = True)
contain_values3.drop(labels = ["All CA Counties"], axis=0, inplace = True)
contain_values3.reset_index(inplace = True)
# Out:
# /opt/anaconda/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# 58 rows
contain_values3[:29].groupby('California Counties')['TOTAL Fully Vaccinated'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
contain_values3[29:].groupby('California Counties')['TOTAL Fully Vaccinated'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
contain_values3[:29].groupby('California Counties')['TOTAL Partially Vaccinated'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
contain_values3[29:].groupby('California Counties')['TOTAL Partially Vaccinated'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
# Limiting our databse to only check for December 2020. We will not see any graph. 
contain_values4 = df[df['Dose Date YYY-DD-MM'].str.contains('2020-12-15')]
#df.drop(labels = ["Unknown", "All CA and Non-CA Counties", "Outside California"], axis=0, inplace = True)
contain_values4.set_index("California Counties", inplace = True)
contain_values4.drop(labels = ["All CA Counties"], axis=0, inplace = True)
contain_values4.reset_index(inplace = True)

# %%
contain_values4[:29].groupby('California Counties')['TOTAL Fully Vaccinated'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
# As expected we don't see any visualization because vaccination was not really started for most people.

# %%
# Trying to see the populatiom

# %%
import requests
response = requests.get("https://www.california-demographics.com/counties_by_population")

if response.status_code == 200:
    print('all good')
else:
    print('error')
# Out:
# all good

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# %%
headings = soup.find_all(['tr'])

# %%
rows = []


for name in headings[1:-1]:
    county = name.find('a').text
    population = name.find('td').find_next('td').find_next('td').text
    
    population = population.replace('\n', '')
    population = population.replace(' ', '')
    population = population.replace(',', '')
   
    
    
   
    rows.append({
        "California Counties": county,
        "Population": int(population)
    })

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

df_pop = pd.DataFrame(rows)
#df_pop

# %%
df_pop.sort_values('California Counties', ascending=True, inplace = True)
#df_pop

# %%
contain_values3.sort_values('California Counties', ascending=True, inplace = True)

# %%
contain_values3["Population"]  = df_pop["Population"].values
contain_values3
# Out:
#    California Counties Dose Date YYY-DD-MM  Total Doses  Cumulative Total  \
# 1              Alameda          2021-08-18         1877           2209568
# 0               Alpine          2021-08-18            0              1509
# 2               Amador          2021-08-18           24             36299
# 3                Butte          2021-08-18          280            186443
# 4            Calaveras          2021-08-18           41             40877
# 5               Colusa          2021-08-18           14             18921
# 6         Contra Costa          2021-08-18         1816           1545626
# 7            Del Norte          2021-08-18           59             19952
# 8            El Dorado          2021-08-18          209            197376
# 9               Fresno          2021-08-18         1466            928182
# 10               Glenn          2021-08-18           67             23518
# 11            Humboldt          2021-08-18          167            144108
# ...

# %%
contain_values3.sort_values('Population', ascending=True, inplace = True)
contain_values3[:28].groupby('California Counties')[['Population', 'TOTAL Fully Vaccinated']].mean().plot.bar()
# Now, comparing vaccinated people with total population
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
contain_values3[28:].groupby('California Counties')[['Population', 'TOTAL Fully Vaccinated']].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
contain_values3[:28].groupby('California Counties')[['Population', 'TOTAL Partially Vaccinated']].mean().plot.bar()
# Checking to see how many people are partially vaccinated
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
contain_values3[28:].groupby('California Counties')[['Population', 'TOTAL Partially Vaccinated']].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
# Here we check only top 4 populated counties of california to see how many people are partially vaccinated
contain_values3.groupby("California Counties")[["Population", "TOTAL Partially Vaccinated"]].mean().loc[["Riverside", "Los Angeles", "San Diego", "Orange"]].plot.bar()
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
# Comparing how many people are fully vaccinated in populated counties. 
contain_values3.groupby("California Counties")[["Population", "TOTAL Fully Vaccinated"]].mean().loc[["Riverside", "Los Angeles", "San Diego", "Orange"]].plot.bar()
# Out:
# <AxesSubplot:xlabel='California Counties'>

# %%
# Now, doing the same comparasion but with least populated counties. 
contain_values3.groupby("California Counties")[["Population", "TOTAL Fully Vaccinated"]].mean().loc[["Alpine", "Sierra", "Modoc", "Trinity"]].plot.bar()
# Out:
# <AxesSubplot:xlabel='California Counties'>
